# %%
import pandas as pd
a=pd.read_excel('flipkart.xlsx',sheet_name=0)
print(a.to_string)
# Out:
# <bound method DataFrame.to_string of                                                   Name     Brand  Ratings  \
# 0       APPLE iPhone 13 Pro Max (Alpine Green, 256 GB)     APPLE      4.6
# 1               APPLE iPhone 13 Pro (Graphite, 256 GB)     APPLE      4.6
# 2               APPLE iPhone 12 Pro (Graphite, 256 GB)     APPLE      4.5
# 3                 APPLE iPhone 12 Pro (Silver, 256 GB)     APPLE      4.5
# 4           SAMSUNG Galaxy S22 Plus 5G (Green, 128 GB)   SAMSUNG      4.5
# ..                                                 ...       ...      ...
# 617                                        Micromax J2  Micromax      3.8
# 618                                        itel Ace 2N      itel      4.1
# 619  I Kall King Talking, Contact icon and Auto Cal...         I      3.6
# 620                                          MTR MT310       MTR      3.8
# 621                                       ANGAGE A2320    ANGAGE      3.4
#
#      No_of_ratings  No_of_reviews  \
# ...

# %%
a=pd.read_excel('flipkart.xlsx',sheet_name=0)
a.drop_duplicates(inplace=True)
print(a.to_string())
# Out:
#                                                               Name       Brand  Ratings  No_of_ratings  No_of_reviews                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Product_features     MSP     MRP  Discount
# ...

# %%
import pandas as pd
a=pd.read_excel('flipkart.xlsx')
a=a.drop('Product_features',axis=1)
print(a)
# Out:
#                                                   Name     Brand  Ratings  \
# 0       APPLE iPhone 13 Pro Max (Alpine Green, 256 GB)     APPLE      4.6
# 1               APPLE iPhone 13 Pro (Graphite, 256 GB)     APPLE      4.6
# 2               APPLE iPhone 12 Pro (Graphite, 256 GB)     APPLE      4.5
# 3                 APPLE iPhone 12 Pro (Silver, 256 GB)     APPLE      4.5
# 4           SAMSUNG Galaxy S22 Plus 5G (Green, 128 GB)   SAMSUNG      4.5
# ..                                                 ...       ...      ...
# 617                                        Micromax J2  Micromax      3.8
# 618                                        itel Ace 2N      itel      4.1
# 619  I Kall King Talking, Contact icon and Auto Cal...         I      3.6
# 620                                          MTR MT310       MTR      3.8
# 621                                       ANGAGE A2320    ANGAGE      3.4
#
#      No_of_ratings  No_of_reviews     MSP     MRP  Discount
# ...

# %%
import pandas as pd
pd.options.display.max_rows=1000
a=pd.read_excel('flipkart.xlsx')
print(a)
# Out:
#                                                   Name       Brand  Ratings  \
# 0       APPLE iPhone 13 Pro Max (Alpine Green, 256 GB)       APPLE      4.6
# 1               APPLE iPhone 13 Pro (Graphite, 256 GB)       APPLE      4.6
# 2               APPLE iPhone 12 Pro (Graphite, 256 GB)       APPLE      4.5
# 3                 APPLE iPhone 12 Pro (Silver, 256 GB)       APPLE      4.5
# 4           SAMSUNG Galaxy S22 Plus 5G (Green, 128 GB)     SAMSUNG      4.5
# 5    SAMSUNG Galaxy S22 Plus 5G (Phantom Black, 128...     SAMSUNG      4.5
# 6                   APPLE iPhone 13 (Midnight, 512 GB)       APPLE      4.7
# 7                  APPLE iPhone 13 (Starlight, 512 GB)       APPLE      4.7
# 8                       APPLE iPhone 13 (Pink, 512 GB)       APPLE      4.7
# 9                       APPLE iPhone 13 (Blue, 512 GB)       APPLE      4.7
# 10               APPLE iPhone 14 Plus (Purple, 256 GB)       APPLE      4.5
# ...

# %%
a=pd.read_excel('flipkart.xlsx')
print(a.describe())
# Out:
#           Ratings  No_of_ratings  No_of_reviews            MSP            MRP  \
# count  622.000000     622.000000     622.000000     622.000000     622.000000
# mean     4.267203   47068.581994    3393.704180   17485.704180   21866.901929
# std      0.188438   77473.913788    5212.468223   17673.110733   21046.019239
# min      3.400000       9.000000       0.000000     679.000000     729.000000
# 25%      4.200000    1948.250000     201.000000    8999.000000   10999.000000
# 50%      4.300000   14318.000000    1277.000000   12999.000000   16999.000000
# 75%      4.400000   58490.000000    4608.000000   17999.000000   22999.000000
# max      4.800000  575591.000000   34744.000000  114900.000000  139900.000000
#
#          Discount
# count  622.000000
# mean    18.442122
# std     11.195627
# min      1.000000
# 25%      9.000000
# 50%     18.000000
# 75%     28.000000
# max     46.000000

# %%
print(a.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              622 non-null    object
#  1   Brand             622 non-null    object
#  2   Ratings           622 non-null    float64
#  3   No_of_ratings     622 non-null    int64
#  4   No_of_reviews     622 non-null    int64
#  5   Product_features  622 non-null    object
#  6   MSP               622 non-null    int64
#  7   MRP               622 non-null    int64
#  8   Discount          622 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 43.9+ KB
# None
